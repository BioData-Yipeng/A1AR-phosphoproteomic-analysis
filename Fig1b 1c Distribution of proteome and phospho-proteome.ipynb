# %%
import pandas as pd
from pandas_profiling import ProfileReport
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df_phosite=pd.read_csv('PerseusNormalizedData.csv')
df_protein=pd.read_csv('protein_PerseusNormalizedData.csv')

# %%
df_phosite.shape, df_protein.shape
# Out:
# ((15685, 25), (8727, 25))

# %%
plt.figure(figsize=(8, 4))
palette = {'WTVeh_1': 'gray',
           'WTVeh_2': 'gray', 
           'WTVeh_3': 'gray',
           'WTVeh_4': 'gray',
           'WTTx_1': 'red', 
           'WTTx_2': 'red',
           'WTTx_3': 'red',
           'WTTx_4': 'red', 
           'KOVeh_1': 'orchid',
           'KOVeh_2': 'orchid',
           'KOVeh_3': 'orchid', 
           'KOVeh_4': 'orchid',
           'KOTx_1': 'orange',
           'KOTx_2': 'orange', 
           'KOTx_3': 'orange',
           'KOTx_4': 'orange'}
chart = sns.violinplot(data=df_phosite.iloc[:,0:16],inner="box",palette=palette)
#chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.yticks(fontsize=16, color='black', fontname='Arial')
plt.xticks([])
#plt.title("Distribution of phosphorylated peptides intensity", fontsize=14)
#plt.ylabel("Normalzied Intensity",fontsize=16)

plt.tight_layout()  # Avoid clipping
plt.savefig("F:/data science/Python/1 paper Rett proteomics/Figures/Fig 1/phosite_violin_plot.png", dpi=600, bbox_inches='tight')  # High-res PNG
plt.show()

# %%
plt.figure(figsize=(8, 4))
palette = {'WTVeh_1': 'gray',
           'WTVeh_2': 'gray', 
           'WTVeh_3': 'gray',
           'WTVeh_4': 'gray',
           'WTTx_1': 'red', 
           'WTTx_2': 'red',
           'WTTx_3': 'red',
           'WTTx_4': 'red', 
           'KOVeh_1': 'orchid',
           'KOVeh_2': 'orchid',
           'KOVeh_3': 'orchid', 
           'KOVeh_4': 'orchid',
           'KOTx_1': 'orange',
           'KOTx_2': 'orange', 
           'KOTx_3': 'orange',
           'KOTx_4': 'orange'}
chart = sns.violinplot(data=df_protein.iloc[:,0:16],inner="box",palette=palette)
#chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.yticks(fontsize=16, color='black', fontname='Arial')
plt.xticks([])
#plt.title("Distribution of protein intensity", fontsize=14)
#plt.ylabel("Normalzied Intensity",fontsize=16)

plt.tight_layout()  # Avoid clipping
plt.savefig("F:/data science/Python/1 paper Rett proteomics/Figures/Fig 1/protein_violin_plot.png", dpi=600, bbox_inches='tight')  # High-res PNG
plt.show()
